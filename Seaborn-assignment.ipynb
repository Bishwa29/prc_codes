# %%
##Seaborn_Assignment

# %%
##Question 1-

##Five plots that can be plotted using the seaborn library are:

##Histogram-used to understand the frequency of a dataset and observe its underlying distribtuion
##Scatter plot-observe the distribution of a dataset and thereby, deduce a relationship between the two coordinates
##Bar plot-allows for comparison of different sets of data among different groups easily
##Box plot-provides a quick visual summary of the variability of values in a dataset
##Violin plot-used to visualize the distribution of numerical data and depiction of summary statistics & density of each variable

# %%
##Question 2-

import seaborn as sns

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x=fmri.timepoint, y=fmri.signal)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
##Question 3-

titanic=sns.load_dataset('titanic')

# %%
sns.pairplot(titanic)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.boxplot(x=titanic.pclass,y=titanic.age)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x=titanic.pclass,y=titanic.fare)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
##Question 4-

diamonds=sns.load_dataset('diamonds')

# %%
sns.histplot(data=diamonds.price)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
##Question 5-

iris=sns.load_dataset('iris')

# %%
sns.pairplot(data=iris,hue='species')

# %%
##Question 6

flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
import pa

df_heatmap = df.pivot_table(index = 'year', columns = 'month', values = 'passengers', aggfunc = 'mean', fill_value = 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import dataframe as df
#       3 df_heatmap = df.pivot_table(index = 'year', columns = 'month', values = 'passengers', aggfunc = 'mean', fill_value = 0)
#
# ModuleNotFoundError: No module named 'dataframe'
